# %%
import gym
import argparse
import numpy as np
import atari_py
from game_models.ddqn_game_model import DDQNTrainer, DDQNSolver
from game_models.ge_game_model import GETrainer, GESolver
from gym_wrappers import MainGymWrapper
# Out:
# Using TensorFlow backend.

# %%
FRAMES_IN_OBSERVATION = 4
FRAME_SIZE = 84
INPUT_SHAPE = (FRAMES_IN_OBSERVATION, FRAME_SIZE, FRAME_SIZE)

# %%
class Atari:

    def __init__(self):
        game_name, game_mode, render, total_step_limit, total_run_limit, clip = "MsPacman","ddqn_training", True,5000000,None,True
        env_name = game_name + "Deterministic-v4"  # Handles frame skipping (4) at every iteration
        env = MainGymWrapper.wrap(gym.make(env_name))
        self._main_loop(self._game_model(game_mode, game_name, env.action_space.n), env, render, total_step_limit, total_run_limit, clip)

    def _main_loop(self, game_model, env, render, total_step_limit, total_run_limit, clip):
        if isinstance(game_model, GETrainer):
            game_model.genetic_evolution(env)

        run = 0
        total_step = 0
        while True:
            if total_run_limit is not None and run >= total_run_limit:
                print ("Reached total run limit of: " + str(total_run_limit))
                exit(0)

            run += 1
            current_state = env.reset()
            step = 0
            score = 0
            while True:
                if total_step >= total_step_limit:
                    print ("Reached total step limit of: " + str(total_step_limit))
                    exit(0)
                total_step += 1
                step += 1

                if render:
                    env.render()

                action = game_model.move(current_state)
                next_state, reward, terminal, info = env.step(action)
                if clip:
                    np.sign(reward)
                score += reward
                game_model.remember(current_state, action, reward, next_state, terminal)
                current_state = next_state

                game_model.step_update(total_step)

                if terminal:
                    game_model.save_run(score, step, run)
                    break



    def _game_model(self, game_mode,game_name, action_space):
        if game_mode == "ddqn_training":
            return DDQNTrainer(game_name, INPUT_SHAPE, action_space)
        elif game_mode == "ddqn_testing":
            return DDQNSolver(game_name, INPUT_SHAPE, action_space)
        elif game_mode == "ge_training":
            return GETrainer(game_name, INPUT_SHAPE, action_space)
        elif game_mode == "ge_testing":
            return GESolver(game_name, INPUT_SHAPE, action_space)
        else:
            print ("Unrecognized mode. Use --help")
            exit

# %%
if __name__ == "__main__":
    Atari()
# Out:
# WARNING:tensorflow:From C:\Users\jshch\AppData\Local\Continuum\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 20, 20)        8224
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 9, 9)          32832
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 7, 7)          36928
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 4617
# =================================================================
# Total params: 1,688,745
# Trainable params: 1,688,745
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 20, 20)        8224
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 9, 9)          32832
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 7, 7)          36928
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# dense_4 (Dense)              (None, 9)                 4617
# =================================================================
# Total params: 1,688,745
# Trainable params: 1,688,745
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\jshch\AppData\Local\Continuum\anaconda3\envs\tensorflow\lib\site-packages\gym\logger.py:30: UserWarning: WARN: <class 'gym_wrappers.NoopResetEnv'> doesn't implement 'step' method, which is required for wrappers derived directly from Wrapper. Deprecated default implementation is used.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# score: (min: 160.0, avg: 233.0, max: 420.0
# {"metric": "score", "value": 233.0}
# step: (min: 420, avg: 483.8, max: 623
# {"metric": "step", "value": 483.8}
# {"metric": "run", "value": 10}
# score: (min: 110.0, avg: 287.0, max: 570.0
# {"metric": "score", "value": 287.0}
# step: (min: 350, avg: 553.5, max: 1112
# {"metric": "step", "value": 553.5}
# {"metric": "run", "value": 20}
# score: (min: 100.0, avg: 205.0, max: 260.0
# {"metric": "score", "value": 205.0}
# step: (min: 308, avg: 429.1, max: 541
# {"metric": "step", "value": 429.1}
# {"metric": "run", "value": 30}
# score: (min: 80.0, avg: 213.0, max: 350.0
# {"metric": "score", "value": 213.0}
# step: (min: 257, avg: 452.3, max: 562
# {"metric": "step", "value": 452.3}
# {"metric": "run", "value": 40}
# score: (min: 140.0, avg: 247.0, max: 460.0
# {"metric": "score", "value": 247.0}
# step: (min: 365, avg: 456.5, max: 619
# {"metric": "step", "value": 456.5}
# {"metric": "run", "value": 50}
# score: (min: 190.0, avg: 243.0, max: 330.0
# {"metric": "score", "value": 243.0}
# step: (min: 373, avg: 479.9, max: 565
# {"metric": "step", "value": 479.9}
# {"metric": "run", "value": 60}
# score: (min: 180.0, avg: 247.0, max: 340.0
# {"metric": "score", "value": 247.0}
# step: (min: 390, avg: 474, max: 640
# {"metric": "step", "value": 474}
# {"metric": "run", "value": 70}
# score: (min: 170.0, avg: 304.0, max: 610.0
# {"metric": "score", "value": 304.0}
# step: (min: 433, avg: 556.3, max: 799
# {"metric": "step", "value": 556.3}
# {"metric": "run", "value": 80}
# score: (min: 90.0, avg: 289.0, max: 790.0
# {"metric": "score", "value": 289.0}
# step: (min: 324, avg: 473.7, max: 867
# {"metric": "step", "value": 473.7}
# {"metric": "run", "value": 90}
# score: (min: 130.0, avg: 232.0, max: 400.0
# {"metric": "score", "value": 232.0}
# step: (min: 281, avg: 432.4, max: 544
# {"metric": "step", "value": 432.4}
# {"metric": "run", "value": 100}
# WARNING:tensorflow:From C:\Users\jshch\AppData\Local\Continuum\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# score: (min: 90.0, avg: 242.0, max: 450.0
# {"metric": "score", "value": 242.0}
# step: (min: 340, avg: 480.7, max: 601
# {"metric": "step", "value": 480.7}
# {"metric": "run", "value": 110}
# loss: (min: 0.15518084168434143, avg: 1.2476764370650053, max: 5
# {"metric": "loss", "value": 1.2476764370650053}
# accuracy: (min: 0.09375, avg: 0.73071875, max: 1.0
# {"metric": "accuracy", "value": 0.73071875}
# q: (min: 14.36251194268465, avg: 17.609707271466256, max: 137.56998586654663
# {"metric": "q", "value": 17.609707271466256}
# score: (min: 130.0, avg: 245.0, max: 650.0
# {"metric": "score", "value": 245.0}
# step: (min: 320, avg: 458.3, max: 910
# {"metric": "step", "value": 458.3}
# {"metric": "run", "value": 120}
# loss: (min: 0.10768647491931915, avg: 0.923847490914166, max: 5
# {"metric": "loss", "value": 0.923847490914166}
# accuracy: (min: 0.09375, avg: 0.71653125, max: 0.96875
# {"metric": "accuracy", "value": 0.71653125}
# q: (min: 14.007241644859313, avg: 16.76394878871381, max: 28.187463760375977
# {"metric": "q", "value": 16.76394878871381}
# loss: (min: 0.08223176002502441, avg: 0.8141520686894655, max: 5
# {"metric": "loss", "value": 0.8141520686894655}
# accuracy: (min: 0.0625, avg: 0.71246875, max: 1.0
# {"metric": "accuracy", "value": 0.71246875}
# q: (min: 14.297838843762875, avg: 16.567569723977744, max: 20.745722979605198
# {"metric": "q", "value": 16.567569723977744}
# score: (min: 150.0, avg: 242.0, max: 480.0
# {"metric": "score", "value": 242.0}
# step: (min: 399, avg: 490.8, max: 705
# {"metric": "step", "value": 490.8}
# {"metric": "run", "value": 130}
# loss: (min: 0.05602708458900452, avg: 0.7559597929418087, max: 5
# {"metric": "loss", "value": 0.7559597929418087}
# accuracy: (min: 0.125, avg: 0.7159375, max: 0.96875
# {"metric": "accuracy", "value": 0.7159375}
# q: (min: 14.32477490991354, avg: 16.4833204527691, max: 19.72985423773527
# {"metric": "q", "value": 16.4833204527691}
# score: (min: 140.0, avg: 282.0, max: 710.0
# {"metric": "score", "value": 282.0}
# step: (min: 312, avg: 525.2, max: 1186
# {"metric": "step", "value": 525.2}
# {"metric": "run", "value": 140}
# loss: (min: 0.061428096145391464, avg: 0.7025981973446905, max: 5
# {"metric": "loss", "value": 0.7025981973446905}
# accuracy: (min: 0.125, avg: 0.712, max: 0.96875
# {"metric": "accuracy", "value": 0.712}
# q: (min: 14.193623778820038, avg: 16.37096762234628, max: 19.924291845560074
# {"metric": "q", "value": 16.37096762234628}
# score: (min: 120.0, avg: 223.0, max: 330.0
# {"metric": "score", "value": 223.0}
# step: (min: 355, avg: 468.7, max: 602
# {"metric": "step", "value": 468.7}
# {"metric": "run", "value": 150}
# loss: (min: 0.06676111370325089, avg: 0.6885063682720065, max: 5
# {"metric": "loss", "value": 0.6885063682720065}
# accuracy: (min: 0.125, avg: 0.7050625, max: 1.0
# {"metric": "accuracy", "value": 0.7050625}
# q: (min: 14.38816890001297, avg: 16.410466209042074, max: 20.453581995368005
# {"metric": "q", "value": 16.410466209042074}
# score: (min: 130.0, avg: 250.0, max: 680.0
# {"metric": "score", "value": 250.0}
# step: (min: 309, avg: 446.1, max: 610
# {"metric": "step", "value": 446.1}
# {"metric": "run", "value": 160}
# loss: (min: 0.07369772344827652, avg: 0.6405037290528417, max: 5
# {"metric": "loss", "value": 0.6405037290528417}
# accuracy: (min: 0.1875, avg: 0.7105625, max: 0.96875
# {"metric": "accuracy", "value": 0.7105625}
# q: (min: 14.373515268862247, avg: 16.43465737195015, max: 24.38789961785078
# {"metric": "q", "value": 16.43465737195015}
# {"metric": "epsilon", "value": 0.9682342352941838}
# {"metric": "total_step", "value": 80000}
# score: (min: 140.0, avg: 214.0, max: 330.0
# {"metric": "score", "value": 214.0}
# step: (min: 361, avg: 444.3, max: 534
# {"metric": "step", "value": 444.3}
# {"metric": "run", "value": 170}
# loss: (min: 0.051834411919116974, avg: 0.676637860480696, max: 5
# {"metric": "loss", "value": 0.676637860480696}
# accuracy: (min: 0.15625, avg: 0.70925, max: 1.0
# {"metric": "accuracy", "value": 0.70925}
# q: (min: 13.828024338185788, avg: 18.202061001095473, max: 25.61863012135029
# {"metric": "q", "value": 18.202061001095473}
# score: (min: 110.0, avg: 210.0, max: 320.0
# {"metric": "score", "value": 210.0}
# step: (min: 312, avg: 470.6, max: 634
# {"metric": "step", "value": 470.6}
# {"metric": "run", "value": 180}
# loss: (min: 0.06381137669086456, avg: 0.6296936209797859, max: 5
# {"metric": "loss", "value": 0.6296936209797859}
# accuracy: (min: 0.09375, avg: 0.70703125, max: 1.0
# {"metric": "accuracy", "value": 0.70703125}
# q: (min: 17.62865997850895, avg: 19.905834197784067, max: 23.252416253089905
# {"metric": "q", "value": 19.905834197784067}
# loss: (min: 0.05301585793495178, avg: 0.5932958726137877, max: 5
# {"metric": "loss", "value": 0.5932958726137877}
# accuracy: (min: 0.09375, avg: 0.71384375, max: 1.0
# {"metric": "accuracy", "value": 0.71384375}
# q: (min: 17.723097143173216, avg: 19.899453449062406, max: 22.855080261826515
# {"metric": "q", "value": 19.899453449062406}
# score: (min: 170.0, avg: 274.0, max: 410.0
# {"metric": "score", "value": 274.0}
# step: (min: 414, avg: 503.3, max: 600
# {"metric": "step", "value": 503.3}
# {"metric": "run", "value": 190}
# loss: (min: 0.055730823427438736, avg: 0.5402680496610701, max: 5
# {"metric": "loss", "value": 0.5402680496610701}
# accuracy: (min: 0.09375, avg: 0.70759375, max: 1.0
# {"metric": "accuracy", "value": 0.70759375}
# q: (min: 17.90894968390465, avg: 19.834513304513393, max: 22.52224190056324
# {"metric": "q", "value": 19.834513304513393}
# score: (min: 180.0, avg: 261.0, max: 370.0
# {"metric": "score", "value": 261.0}
# step: (min: 330, avg: 457.4, max: 550
# {"metric": "step", "value": 457.4}
# {"metric": "run", "value": 200}
# loss: (min: 0.030141785740852356, avg: 0.5756877884268761, max: 5
# {"metric": "loss", "value": 0.5756877884268761}
# accuracy: (min: 0.1875, avg: 0.71978125, max: 1.0
# {"metric": "accuracy", "value": 0.71978125}
# q: (min: 17.740693452954293, avg: 19.843931699451804, max: 26.171318315267563
# {"metric": "q", "value": 19.843931699451804}
# score: (min: 110.0, avg: 273.0, max: 420.0
# {"metric": "score", "value": 273.0}
# step: (min: 301, avg: 518.9, max: 689
# {"metric": "step", "value": 518.9}
# {"metric": "run", "value": 210}
# loss: (min: 0.05635412782430649, avg: 0.5510846193134785, max: 5
# {"metric": "loss", "value": 0.5510846193134785}
# accuracy: (min: 0.15625, avg: 0.7261875, max: 0.96875
# {"metric": "accuracy", "value": 0.7261875}
# q: (min: 17.685490940213203, avg: 19.929228612509668, max: 27.636943387389184
# {"metric": "q", "value": 19.929228612509668}
# score: (min: 140.0, avg: 226.0, max: 310.0
# {"metric": "score", "value": 226.0}
# step: (min: 415, avg: 455.1, max: 498
# {"metric": "step", "value": 455.1}
# {"metric": "run", "value": 220}
# loss: (min: 0.06031094118952751, avg: 0.5066355365663767, max: 5
# {"metric": "loss", "value": 0.5066355365663767}
# accuracy: (min: 0.125, avg: 0.731, max: 1.0
# {"metric": "accuracy", "value": 0.731}
# q: (min: 17.509830650389194, avg: 19.880434002838435, max: 25.727834396362304
# {"metric": "q", "value": 19.880434002838435}
# score: (min: 120.0, avg: 340.0, max: 960.0
# {"metric": "score", "value": 340.0}
# step: (min: 314, avg: 473.6, max: 710
# {"metric": "step", "value": 473.6}
# {"metric": "run", "value": 230}
# loss: (min: 0.051236219704151154, avg: 0.48204935326427223, max: 5
# {"metric": "loss", "value": 0.48204935326427223}
# accuracy: (min: 0.1875, avg: 0.7126875, max: 0.96875
# {"metric": "accuracy", "value": 0.7126875}
# q: (min: 17.810149142742155, avg: 19.814474192754925, max: 22.19192151963711
# {"metric": "q", "value": 19.814474192754925}
# loss: (min: 0.041059717535972595, avg: 0.4842416556663811, max: 5
# {"metric": "loss", "value": 0.4842416556663811}
# accuracy: (min: 0.09375, avg: 0.721, max: 1.0
# {"metric": "accuracy", "value": 0.721}
# q: (min: 17.985193493664266, avg: 19.802440135729015, max: 22.633763594925405
# {"metric": "q", "value": 19.802440135729015}
# score: (min: 70.0, avg: 239.0, max: 410.0
# {"metric": "score", "value": 239.0}
# step: (min: 211, avg: 453.7, max: 610
# {"metric": "step", "value": 453.7}
# {"metric": "run", "value": 240}
# loss: (min: 0.04108535498380661, avg: 0.44734454637765886, max: 5
# {"metric": "loss", "value": 0.44734454637765886}
# accuracy: (min: 0.125, avg: 0.7200625, max: 1.0
# {"metric": "accuracy", "value": 0.7200625}
# q: (min: 17.826236839592458, avg: 19.757883639134466, max: 22.385481774806976
# {"metric": "q", "value": 19.757883639134466}
# score: (min: 170.0, avg: 252.0, max: 330.0
# {"metric": "score", "value": 252.0}
# step: (min: 318, avg: 448.7, max: 571
# {"metric": "step", "value": 448.7}
# {"metric": "run", "value": 250}
# {"metric": "epsilon", "value": 0.9258812941178015}
# {"metric": "total_step", "value": 120000}
# loss: (min: 0.04585921764373779, avg: 0.5888264212720096, max: 5
# {"metric": "loss", "value": 0.5888264212720096}
# accuracy: (min: 0.21875, avg: 0.71809375, max: 1.0
# {"metric": "accuracy", "value": 0.71809375}
# q: (min: 17.263518294990064, avg: 20.3897848324129, max: 27.56476364403963
# {"metric": "q", "value": 20.3897848324129}
# score: (min: 160.0, avg: 246.0, max: 400.0
# {"metric": "score", "value": 246.0}
# step: (min: 348, avg: 422.9, max: 527
# {"metric": "step", "value": 422.9}
# {"metric": "run", "value": 260}
# loss: (min: 0.05866887420415878, avg: 0.5972627317160368, max: 5
# {"metric": "loss", "value": 0.5972627317160368}
# accuracy: (min: 0.21875, avg: 0.7208125, max: 0.96875
# {"metric": "accuracy", "value": 0.7208125}
# q: (min: 18.538450781404972, avg: 20.974894319685102, max: 23.90036417543888
# {"metric": "q", "value": 20.974894319685102}
# score: (min: 130.0, avg: 247.0, max: 310.0
# {"metric": "score", "value": 247.0}
# step: (min: 425, avg: 472.7, max: 541
# {"metric": "step", "value": 472.7}
# {"metric": "run", "value": 270}
# loss: (min: 0.062124308198690414, avg: 0.6167681538574398, max: 5
# {"metric": "loss", "value": 0.6167681538574398}
# accuracy: (min: 0.28125, avg: 0.73259375, max: 0.96875
# {"metric": "accuracy", "value": 0.73259375}
# q: (min: 18.732441168129444, avg: 21.04625225434631, max: 28.648458221554755
# {"metric": "q", "value": 21.04625225434631}
# score: (min: 160.0, avg: 276.0, max: 520.0
# {"metric": "score", "value": 276.0}
# step: (min: 328, avg: 463.3, max: 691
# {"metric": "step", "value": 463.3}
# {"metric": "run", "value": 280}
# loss: (min: 0.07283681631088257, avg: 0.548842241987586, max: 5
# {"metric": "loss", "value": 0.548842241987586}
# accuracy: (min: 0.25, avg: 0.72496875, max: 1.0
# {"metric": "accuracy", "value": 0.72496875}
# q: (min: 18.85476149916649, avg: 20.97242633115679, max: 26.544777781665324
# {"metric": "q", "value": 20.97242633115679}
# score: (min: 120.0, avg: 272.0, max: 430.0
# {"metric": "score", "value": 272.0}
# step: (min: 313, avg: 459.9, max: 572
# {"metric": "step", "value": 459.9}
# {"metric": "run", "value": 290}
# loss: (min: 0.0700349360704422, avg: 0.5111458671241998, max: 5
# {"metric": "loss", "value": 0.5111458671241998}
# accuracy: (min: 0.25, avg: 0.7340625, max: 1.0
# {"metric": "accuracy", "value": 0.7340625}
# q: (min: 18.792826938033105, avg: 20.992285836518406, max: 32.50660498201847
# {"metric": "q", "value": 20.992285836518406}
# score: (min: 140.0, avg: 311.0, max: 700.0
# {"metric": "score", "value": 311.0}
# step: (min: 299, avg: 468.8, max: 704
# {"metric": "step", "value": 468.8}
# {"metric": "run", "value": 300}
# loss: (min: 0.06612592935562134, avg: 0.5317550620809197, max: 5
# {"metric": "loss", "value": 0.5317550620809197}
# accuracy: (min: 0.25, avg: 0.73109375, max: 1.0
# {"metric": "accuracy", "value": 0.73109375}
# q: (min: 18.658849756121636, avg: 20.990775583002865, max: 32.01777739554644
# {"metric": "q", "value": 20.990775583002865}
# loss: (min: 0.06654825806617737, avg: 0.4957663346230984, max: 5
# {"metric": "loss", "value": 0.4957663346230984}
# accuracy: (min: 0.21875, avg: 0.725375, max: 0.96875
# {"metric": "accuracy", "value": 0.725375}
# q: (min: 18.99584006369114, avg: 20.926718366034926, max: 26.384481342136862
# {"metric": "q", "value": 20.926718366034926}
# score: (min: 180.0, avg: 317.0, max: 720.0
# {"metric": "score", "value": 317.0}
# step: (min: 371, avg: 547.2, max: 1113
# {"metric": "step", "value": 547.2}
# {"metric": "run", "value": 310}
# loss: (min: 0.073177270591259, avg: 0.5161204761490226, max: 5
# {"metric": "loss", "value": 0.5161204761490226}
# accuracy: (min: 0.125, avg: 0.73803125, max: 1.0
# {"metric": "accuracy", "value": 0.73803125}
# q: (min: 18.69151702463627, avg: 20.986084422717987, max: 28.012240565419198
# {"metric": "q", "value": 20.986084422717987}
# score: (min: 110.0, avg: 209.0, max: 310.0
# {"metric": "score", "value": 209.0}
# step: (min: 355, avg: 426.6, max: 509
# {"metric": "step", "value": 426.6}
# {"metric": "run", "value": 320}
# loss: (min: 0.03704329580068588, avg: 0.4927914880812168, max: 5
# {"metric": "loss", "value": 0.4927914880812168}
# accuracy: (min: 0.21875, avg: 0.73653125, max: 1.0
# {"metric": "accuracy", "value": 0.73653125}
# q: (min: 18.90595981359482, avg: 20.994817663150727, max: 27.59111243903637
# {"metric": "q", "value": 20.994817663150727}
# score: (min: 180.0, avg: 258.0, max: 320.0
# {"metric": "score", "value": 258.0}
# step: (min: 380, avg: 459.3, max: 509
# {"metric": "step", "value": 459.3}
# {"metric": "run", "value": 330}
# loss: (min: 0.03552946820855141, avg: 0.45089088307693603, max: 5
# {"metric": "loss", "value": 0.45089088307693603}
# accuracy: (min: 0.25, avg: 0.72965625, max: 1.0
# {"metric": "accuracy", "value": 0.72965625}
# q: (min: 19.09110048800707, avg: 20.894264204556645, max: 24.39179364144802
# {"metric": "q", "value": 20.894264204556645}
# {"metric": "epsilon", "value": 0.8835283529414192}
# {"metric": "total_step", "value": 160000}
# score: (min: 170.0, avg: 294.0, max: 500.0
# {"metric": "score", "value": 294.0}
# step: (min: 327, avg: 489.2, max: 648
# {"metric": "step", "value": 489.2}
# {"metric": "run", "value": 340}
# loss: (min: 0.047939177602529526, avg: 0.5644932201169431, max: 5
# {"metric": "loss", "value": 0.5644932201169431}
# accuracy: (min: 0.25, avg: 0.7249375, max: 1.0
# {"metric": "accuracy", "value": 0.7249375}
# q: (min: 18.651018530726432, avg: 21.71587698936641, max: 27.787690968513488
# {"metric": "q", "value": 21.71587698936641}
# score: (min: 130.0, avg: 247.0, max: 360.0
# {"metric": "score", "value": 247.0}
# step: (min: 305, avg: 473.7, max: 663
# {"metric": "step", "value": 473.7}
# {"metric": "run", "value": 350}
# loss: (min: 0.08761105686426163, avg: 0.5835130646303296, max: 5
# {"metric": "loss", "value": 0.5835130646303296}
# accuracy: (min: 0.25, avg: 0.7164375, max: 0.96875
# {"metric": "accuracy", "value": 0.7164375}
# q: (min: 19.97939526617527, avg: 22.447220256831645, max: 25.760406342744826
# {"metric": "q", "value": 22.447220256831645}
# loss: (min: 0.0730670839548111, avg: 0.5193342727720738, max: 5
# {"metric": "loss", "value": 0.5193342727720738}
# accuracy: (min: 0.21875, avg: 0.72875, max: 1.0
# {"metric": "accuracy", "value": 0.72875}
# q: (min: 19.65911266952753, avg: 22.397031494710447, max: 29.585508700609207
# {"metric": "q", "value": 22.397031494710447}
# score: (min: 170.0, avg: 284.0, max: 860.0
# {"metric": "score", "value": 284.0}
# step: (min: 310, avg: 478, max: 922
# {"metric": "step", "value": 478}
# {"metric": "run", "value": 360}
# loss: (min: 0.07854633033275604, avg: 0.5257129151150585, max: 5
# {"metric": "loss", "value": 0.5257129151150585}
# accuracy: (min: 0.25, avg: 0.72321875, max: 1.0
# {"metric": "accuracy", "value": 0.72321875}
# q: (min: 19.598334756493568, avg: 22.4117410822621, max: 27.721631413102152
# {"metric": "q", "value": 22.4117410822621}
# score: (min: 120.0, avg: 317.0, max: 670.0
# {"metric": "score", "value": 317.0}
# step: (min: 309, avg: 510.1, max: 746
# {"metric": "step", "value": 510.1}
# {"metric": "run", "value": 370}
# loss: (min: 0.06990277767181396, avg: 0.5178087099790573, max: 5
# {"metric": "loss", "value": 0.5178087099790573}
# accuracy: (min: 0.25, avg: 0.73434375, max: 0.96875
# {"metric": "accuracy", "value": 0.73434375}
# q: (min: 19.85899344563484, avg: 22.444011097690165, max: 27.723588709831237
# {"metric": "q", "value": 22.444011097690165}
# score: (min: 220.0, avg: 267.0, max: 350.0
# {"metric": "score", "value": 267.0}
# step: (min: 363, avg: 449.2, max: 556
# {"metric": "step", "value": 449.2}
# {"metric": "run", "value": 380}
# loss: (min: 0.07250805199146271, avg: 0.5058000682368875, max: 5
# {"metric": "loss", "value": 0.5058000682368875}
# accuracy: (min: 0.21875, avg: 0.72690625, max: 1.0
# {"metric": "accuracy", "value": 0.72690625}
# q: (min: 20.08724142074585, avg: 22.402165533390043, max: 27.214698845148085
# {"metric": "q", "value": 22.402165533390043}
# score: (min: 190.0, avg: 480.0, max: 1100.0
# {"metric": "score", "value": 480.0}
# step: (min: 350, avg: 581.5, max: 969
# {"metric": "step", "value": 581.5}
# {"metric": "run", "value": 390}
# loss: (min: 0.07133989036083221, avg: 0.5104407788664103, max: 5
# {"metric": "loss", "value": 0.5104407788664103}
# accuracy: (min: 0.25, avg: 0.72621875, max: 0.96875
# {"metric": "accuracy", "value": 0.72621875}
# q: (min: 19.48326563715935, avg: 22.435548404499887, max: 33.393044975399974
# {"metric": "q", "value": 22.435548404499887}
# loss: (min: 0.05807768926024437, avg: 0.488678961250931, max: 5
# {"metric": "loss", "value": 0.488678961250931}
# accuracy: (min: 0.3125, avg: 0.72940625, max: 1.0
# {"metric": "accuracy", "value": 0.72940625}
# q: (min: 20.06452300697565, avg: 22.384472102254033, max: 29.006337825655937
# {"metric": "q", "value": 22.384472102254033}
# score: (min: 130.0, avg: 242.0, max: 420.0
# {"metric": "score", "value": 242.0}
# step: (min: 306, avg: 470.7, max: 675
# {"metric": "step", "value": 470.7}
# {"metric": "run", "value": 400}
# loss: (min: 0.06902056187391281, avg: 0.4580937937274575, max: 5
# {"metric": "loss", "value": 0.4580937937274575}
# accuracy: (min: 0.25, avg: 0.731375, max: 1.0
# {"metric": "accuracy", "value": 0.731375}
# q: (min: 20.127744793891907, avg: 22.417926720408797, max: 28.83972209751606
# {"metric": "q", "value": 22.417926720408797}
# score: (min: 220.0, avg: 278.0, max: 380.0
# {"metric": "score", "value": 278.0}
# step: (min: 406, avg: 456.7, max: 533
# {"metric": "step", "value": 456.7}
# {"metric": "run", "value": 410}
# loss: (min: 0.0748729407787323, avg: 0.4379553497731686, max: 5
# {"metric": "loss", "value": 0.4379553497731686}
# accuracy: (min: 0.28125, avg: 0.72871875, max: 0.96875
# {"metric": "accuracy", "value": 0.72871875}
# q: (min: 19.566487431526184, avg: 22.42132359303802, max: 29.23675182282925
# {"metric": "q", "value": 22.42132359303802}
# {"metric": "epsilon", "value": 0.8411754117650369}
# {"metric": "total_step", "value": 200000}
# score: (min: 260.0, avg: 434.0, max: 1040.0
# {"metric": "score", "value": 434.0}
# step: (min: 423, avg: 546.7, max: 776
# {"metric": "step", "value": 546.7}
# {"metric": "run", "value": 420}
# loss: (min: 0.07843758910894394, avg: 0.6415093694329261, max: 5
# {"metric": "loss", "value": 0.6415093694329261}
# accuracy: (min: 0.28125, avg: 0.730125, max: 1.0
# {"metric": "accuracy", "value": 0.730125}
# q: (min: 20.23569306731224, avg: 23.487448140007555, max: 30.80097859561443
# {"metric": "q", "value": 23.487448140007555}
# score: (min: 170.0, avg: 320.0, max: 670.0
# {"metric": "score", "value": 320.0}
# step: (min: 340, avg: 512, max: 960
# {"metric": "step", "value": 512}
# {"metric": "run", "value": 430}
# loss: (min: 0.11105214804410934, avg: 0.6773278951719404, max: 5
# {"metric": "loss", "value": 0.6773278951719404}
# accuracy: (min: 0.28125, avg: 0.733125, max: 1.0
# {"metric": "accuracy", "value": 0.733125}
# q: (min: 21.334963760972023, avg: 24.481803985834123, max: 36.506995422244074
# {"metric": "q", "value": 24.481803985834123}
# loss: (min: 0.09447349607944489, avg: 0.6647557462900877, max: 5
# {"metric": "loss", "value": 0.6647557462900877}
# accuracy: (min: 0.3125, avg: 0.73353125, max: 0.9375
# {"metric": "accuracy", "value": 0.73353125}
# q: (min: 21.880505814552308, avg: 24.55172904763639, max: 31.267702855467796
# {"metric": "q", "value": 24.55172904763639}
# score: (min: 200.0, avg: 316.0, max: 900.0
# {"metric": "score", "value": 316.0}
# step: (min: 358, avg: 468.4, max: 632
# {"metric": "step", "value": 468.4}
# {"metric": "run", "value": 440}
# loss: (min: 0.06344670802354813, avg: 0.6322985558286309, max: 5
# {"metric": "loss", "value": 0.6322985558286309}
# accuracy: (min: 0.1875, avg: 0.7374375, max: 1.0
# {"metric": "accuracy", "value": 0.7374375}
# q: (min: 21.40511045575142, avg: 24.498877221411764, max: 37.024881042838096
# {"metric": "q", "value": 24.498877221411764}
# score: (min: 240.0, avg: 359.0, max: 580.0
# {"metric": "score", "value": 359.0}
# step: (min: 367, avg: 550, max: 804
# {"metric": "step", "value": 550}
# {"metric": "run", "value": 450}
# loss: (min: 0.102614626288414, avg: 0.6131353536620736, max: 5
# {"metric": "loss", "value": 0.6131353536620736}
# accuracy: (min: 0.3125, avg: 0.73321875, max: 1.0
# {"metric": "accuracy", "value": 0.73321875}
# q: (min: 21.43609290719032, avg: 24.396537613462506, max: 30.58597180902958
# {"metric": "q", "value": 24.396537613462506}
# score: (min: 120.0, avg: 384.0, max: 740.0
# {"metric": "score", "value": 384.0}
# step: (min: 347, avg: 540.1, max: 789
# {"metric": "step", "value": 540.1}
# {"metric": "run", "value": 460}
# loss: (min: 0.08574934303760529, avg: 0.5996540764868259, max: 5
# {"metric": "loss", "value": 0.5996540764868259}
# accuracy: (min: 0.3125, avg: 0.73875, max: 1.0
# {"metric": "accuracy", "value": 0.73875}
# q: (min: 21.158826103210448, avg: 24.55822202763915, max: 31.84404891371727
# {"metric": "q", "value": 24.55822202763915}
# loss: (min: 0.0788782462477684, avg: 0.5827861024960875, max: 5
# {"metric": "loss", "value": 0.5827861024960875}
# accuracy: (min: 0.28125, avg: 0.72971875, max: 0.96875
# {"metric": "accuracy", "value": 0.72971875}
# q: (min: 21.022051677703857, avg: 24.45132584999621, max: 33.19530854225159
# {"metric": "q", "value": 24.45132584999621}
# score: (min: 230.0, avg: 311.0, max: 530.0
# {"metric": "score", "value": 311.0}
# step: (min: 395, avg: 465.7, max: 617
# {"metric": "step", "value": 465.7}
# {"metric": "run", "value": 470}
# loss: (min: 0.07080818712711334, avg: 0.6111558261215687, max: 5
# {"metric": "loss", "value": 0.6111558261215687}
# accuracy: (min: 0.3125, avg: 0.743625, max: 1.0
# {"metric": "accuracy", "value": 0.743625}
# q: (min: 21.719238238334654, avg: 24.53464744310707, max: 37.4941386282444
# {"metric": "q", "value": 24.53464744310707}
# score: (min: 260.0, avg: 520.0, max: 1110.0
# {"metric": "score", "value": 520.0}
# step: (min: 432, avg: 601.5, max: 817
# {"metric": "step", "value": 601.5}
# {"metric": "run", "value": 480}
# loss: (min: 0.1015687882900238, avg: 0.6066017850637436, max: 5
# {"metric": "loss", "value": 0.6066017850637436}
# accuracy: (min: 0.25, avg: 0.7375, max: 0.96875
# {"metric": "accuracy", "value": 0.7375}
# q: (min: 21.71070491731167, avg: 24.53332801398933, max: 32.72306797504425
# {"metric": "q", "value": 24.53332801398933}
# score: (min: 140.0, avg: 308.0, max: 520.0
# {"metric": "score", "value": 308.0}
# step: (min: 301, avg: 503.2, max: 777
# {"metric": "step", "value": 503.2}
# {"metric": "run", "value": 490}
# loss: (min: 0.10904659330844879, avg: 0.5778490375354886, max: 5
# {"metric": "loss", "value": 0.5778490375354886}
# accuracy: (min: 0.25, avg: 0.73846875, max: 0.96875
# {"metric": "accuracy", "value": 0.73846875}
# q: (min: 21.711047185361387, avg: 24.445397043606043, max: 36.798142241239546
# {"metric": "q", "value": 24.445397043606043}
# {"metric": "epsilon", "value": 0.7988224705886545}
# {"metric": "total_step", "value": 240000}
# score: (min: 230.0, avg: 327.0, max: 710.0
# {"metric": "score", "value": 327.0}
# step: (min: 369, avg: 481.8, max: 653
# {"metric": "step", "value": 481.8}
# {"metric": "run", "value": 500}
# loss: (min: 0.07999137043952942, avg: 0.6873189784362912, max: 5
# {"metric": "loss", "value": 0.6873189784362912}
# accuracy: (min: 0.28125, avg: 0.72775, max: 0.96875
# {"metric": "accuracy", "value": 0.72775}
# q: (min: 21.351781058311463, avg: 25.42564649503857, max: 32.889790917038916
# {"metric": "q", "value": 25.42564649503857}
# loss: (min: 0.11066913604736328, avg: 0.7456215901970863, max: 5
# {"metric": "loss", "value": 0.7456215901970863}
# accuracy: (min: 0.1875, avg: 0.72884375, max: 0.96875
# {"metric": "accuracy", "value": 0.72884375}
# q: (min: 22.903690137267112, avg: 26.29466358428359, max: 34.357260356545446
# {"metric": "q", "value": 26.29466358428359}
# score: (min: 220.0, avg: 376.0, max: 1090.0
# {"metric": "score", "value": 376.0}
# step: (min: 427, avg: 543.3, max: 897
# {"metric": "step", "value": 543.3}
# {"metric": "run", "value": 510}
# loss: (min: 0.13228189945220947, avg: 0.7132855409830808, max: 5
# {"metric": "loss", "value": 0.7132855409830808}
# accuracy: (min: 0.28125, avg: 0.7314375, max: 0.96875
# {"metric": "accuracy", "value": 0.7314375}
# q: (min: 22.68789198040962, avg: 26.27697252324164, max: 31.337195014953615
# {"metric": "q", "value": 26.27697252324164}
# score: (min: 170.0, avg: 355.0, max: 610.0
# {"metric": "score", "value": 355.0}
# step: (min: 300, avg: 514.7, max: 739
# {"metric": "step", "value": 514.7}
# {"metric": "run", "value": 520}
# loss: (min: 0.13840927183628082, avg: 0.7233816266953945, max: 5
# {"metric": "loss", "value": 0.7233816266953945}
# accuracy: (min: 0.3125, avg: 0.75040625, max: 1.0
# {"metric": "accuracy", "value": 0.75040625}
# q: (min: 22.56661660671234, avg: 26.498800861589014, max: 39.86331196844578
# {"metric": "q", "value": 26.498800861589014}
# score: (min: 160.0, avg: 337.0, max: 700.0
# {"metric": "score", "value": 337.0}
# step: (min: 342, avg: 504.6, max: 746
# {"metric": "step", "value": 504.6}
# {"metric": "run", "value": 530}
# loss: (min: 0.11713726818561554, avg: 0.7025848133116961, max: 5
# {"metric": "loss", "value": 0.7025848133116961}
# accuracy: (min: 0.25, avg: 0.73775, max: 1.0
# {"metric": "accuracy", "value": 0.73775}
# q: (min: 23.031411739587785, avg: 26.331728797341587, max: 32.56307469069958
# {"metric": "q", "value": 26.331728797341587}
# loss: (min: 0.11263159662485123, avg: 0.6981923445463181, max: 5
# {"metric": "loss", "value": 0.6981923445463181}
# accuracy: (min: 0.28125, avg: 0.7311875, max: 1.0
# {"metric": "accuracy", "value": 0.7311875}
# q: (min: 23.030334584712982, avg: 26.25003107985467, max: 41.8782327568531
# {"metric": "q", "value": 26.25003107985467}
# score: (min: 170.0, avg: 372.0, max: 640.0
# {"metric": "score", "value": 372.0}
# step: (min: 413, avg: 509.3, max: 657
# {"metric": "step", "value": 509.3}
# {"metric": "run", "value": 540}
# loss: (min: 0.11461267620325089, avg: 0.669977107681334, max: 5
# {"metric": "loss", "value": 0.669977107681334}
# accuracy: (min: 0.3125, avg: 0.73271875, max: 1.0
# {"metric": "accuracy", "value": 0.73271875}
# q: (min: 22.475565491318704, avg: 26.260429184153377, max: 38.18173529028893
# {"metric": "q", "value": 26.260429184153377}
# score: (min: 210.0, avg: 335.0, max: 720.0
# {"metric": "score", "value": 335.0}
# step: (min: 364, avg: 476.7, max: 697
# {"metric": "step", "value": 476.7}
# {"metric": "run", "value": 550}
# loss: (min: 0.11666466295719147, avg: 0.6129432947039605, max: 5
# {"metric": "loss", "value": 0.6129432947039605}
# accuracy: (min: 0.3125, avg: 0.7311875, max: 1.0
# {"metric": "accuracy", "value": 0.7311875}
# q: (min: 22.890361822843552, avg: 26.16926287517518, max: 30.248001386523246
# {"metric": "q", "value": 26.16926287517518}
# score: (min: 200.0, avg: 387.0, max: 770.0
# {"metric": "score", "value": 387.0}
# step: (min: 375, avg: 496.7, max: 622
# {"metric": "step", "value": 496.7}
# {"metric": "run", "value": 560}
# loss: (min: 0.09409407526254654, avg: 0.6645778580009938, max: 5
# {"metric": "loss", "value": 0.6645778580009938}
# accuracy: (min: 0.3125, avg: 0.732375, max: 1.0
# {"metric": "accuracy", "value": 0.732375}
# q: (min: 22.965650844573975, avg: 26.28852769806534, max: 33.978870485425
# {"metric": "q", "value": 26.28852769806534}
# score: (min: 130.0, avg: 400.0, max: 1130.0
# {"metric": "score", "value": 400.0}
# step: (min: 310, avg: 489.9, max: 692
# {"metric": "step", "value": 489.9}
# {"metric": "run", "value": 570}
# loss: (min: 0.09855908155441284, avg: 0.6682765306383371, max: 5
# {"metric": "loss", "value": 0.6682765306383371}
# accuracy: (min: 0.25, avg: 0.7398125, max: 0.96875
# {"metric": "accuracy", "value": 0.7398125}
# q: (min: 23.020799337029455, avg: 26.312674542485773, max: 39.20083132982254
# {"metric": "q", "value": 26.312674542485773}
# {"metric": "epsilon", "value": 0.7564695294122722}
# {"metric": "total_step", "value": 280000}
# score: (min: 170.0, avg: 332.0, max: 670.0
# {"metric": "score", "value": 332.0}
# step: (min: 313, avg: 467.3, max: 630
# {"metric": "step", "value": 467.3}
# {"metric": "run", "value": 580}
# loss: (min: 0.08929438889026642, avg: 0.8047150261402131, max: 5
# {"metric": "loss", "value": 0.8047150261402131}
# accuracy: (min: 0.25, avg: 0.73109375, max: 0.96875
# {"metric": "accuracy", "value": 0.73109375}
# q: (min: 22.96231791436672, avg: 27.173350438823103, max: 40.66253143966198
# {"metric": "q", "value": 27.173350438823103}
# loss: (min: 0.17286694049835205, avg: 0.8793527927100658, max: 5
# {"metric": "loss", "value": 0.8793527927100658}
# accuracy: (min: 0.28125, avg: 0.72715625, max: 0.96875
# {"metric": "accuracy", "value": 0.72715625}
# q: (min: 24.032355098128317, avg: 27.80827735758245, max: 33.43021333515644
# {"metric": "q", "value": 27.80827735758245}
# score: (min: 200.0, avg: 429.0, max: 970.0
# {"metric": "score", "value": 429.0}
# step: (min: 351, avg: 529.8, max: 763
# {"metric": "step", "value": 529.8}
# {"metric": "run", "value": 590}
# loss: (min: 0.14069421589374542, avg: 0.8049548107683658, max: 5
# {"metric": "loss", "value": 0.8049548107683658}
# accuracy: (min: 0.34375, avg: 0.73065625, max: 0.96875
# {"metric": "accuracy", "value": 0.73065625}
# q: (min: 23.622772339582443, avg: 27.829394893972278, max: 40.769771393537525
# {"metric": "q", "value": 27.829394893972278}
# score: (min: 240.0, avg: 547.0, max: 970.0
# {"metric": "score", "value": 547.0}
# step: (min: 380, avg: 572.6, max: 762
# {"metric": "step", "value": 572.6}
# {"metric": "run", "value": 600}
# loss: (min: 0.1476030945777893, avg: 0.8526862004250289, max: 5
# {"metric": "loss", "value": 0.8526862004250289}
# accuracy: (min: 0.375, avg: 0.74009375, max: 1.0
# {"metric": "accuracy", "value": 0.74009375}
# q: (min: 24.359232435226442, avg: 27.943816596663595, max: 40.8074467676878
# {"metric": "q", "value": 27.943816596663595}
# loss: (min: 0.1247732937335968, avg: 0.8371329639703036, max: 5
# {"metric": "loss", "value": 0.8371329639703036}
# accuracy: (min: 0.375, avg: 0.738375, max: 1.0
# {"metric": "accuracy", "value": 0.738375}
# q: (min: 23.767645531892775, avg: 27.9086847908026, max: 41.15380571782589
# {"metric": "q", "value": 27.9086847908026}
# score: (min: 220.0, avg: 506.0, max: 1060.0
# {"metric": "score", "value": 506.0}
# step: (min: 376, avg: 545.6, max: 776
# {"metric": "step", "value": 545.6}
# {"metric": "run", "value": 610}
# loss: (min: 0.11864975094795227, avg: 0.7708362516462803, max: 5
# {"metric": "loss", "value": 0.7708362516462803}
# accuracy: (min: 0.375, avg: 0.7343125, max: 1.0
# {"metric": "accuracy", "value": 0.7343125}
# q: (min: 24.099127576351165, avg: 27.780601528922617, max: 39.20036738336086
# {"metric": "q", "value": 27.780601528922617}
# score: (min: 190.0, avg: 386.0, max: 670.0
# {"metric": "score", "value": 386.0}
# step: (min: 313, avg: 504.8, max: 683
# {"metric": "step", "value": 504.8}
# {"metric": "run", "value": 620}
# loss: (min: 0.11480768024921417, avg: 0.8184217555150389, max: 5
# {"metric": "loss", "value": 0.8184217555150389}
# accuracy: (min: 0.40625, avg: 0.74715625, max: 1.0
# {"metric": "accuracy", "value": 0.74715625}
# q: (min: 23.18292706847191, avg: 27.75303038237065, max: 40.62037749826908
# {"metric": "q", "value": 27.75303038237065}
# score: (min: 140.0, avg: 347.0, max: 570.0
# {"metric": "score", "value": 347.0}
# step: (min: 297, avg: 495.2, max: 754
# {"metric": "step", "value": 495.2}
# {"metric": "run", "value": 630}
# loss: (min: 0.12870299816131592, avg: 0.7634107094407082, max: 5
# {"metric": "loss", "value": 0.7634107094407082}
# accuracy: (min: 0.34375, avg: 0.74228125, max: 1.0
# {"metric": "accuracy", "value": 0.74228125}
# q: (min: 23.592006927728654, avg: 27.812523840531707, max: 38.6573181772232
# {"metric": "q", "value": 27.812523840531707}
# score: (min: 150.0, avg: 285.0, max: 420.0
# {"metric": "score", "value": 285.0}
# step: (min: 248, avg: 426.2, max: 627
# {"metric": "step", "value": 426.2}
# {"metric": "run", "value": 640}
# loss: (min: 0.1194612979888916, avg: 0.7354951766133309, max: 5
# {"metric": "loss", "value": 0.7354951766133309}
# accuracy: (min: 0.28125, avg: 0.73525, max: 0.9375
# {"metric": "accuracy", "value": 0.73525}
# q: (min: 22.98300682067871, avg: 27.80999831817329, max: 36.14722489356995
# {"metric": "q", "value": 27.80999831817329}
# score: (min: 110.0, avg: 411.0, max: 860.0
# {"metric": "score", "value": 411.0}
# step: (min: 275, avg: 481, max: 709
# {"metric": "step", "value": 481}
# {"metric": "run", "value": 650}
# loss: (min: 0.10036308318376541, avg: 0.7557445961087942, max: 5
# {"metric": "loss", "value": 0.7557445961087942}
# accuracy: (min: 0.34375, avg: 0.738, max: 0.96875
# {"metric": "accuracy", "value": 0.738}
# q: (min: 24.18823249459267, avg: 27.690282631718816, max: 34.768002955913545
# {"metric": "q", "value": 27.690282631718816}
# {"metric": "epsilon", "value": 0.7141165882358899}
# {"metric": "total_step", "value": 320000}
# loss: (min: 0.1319698691368103, avg: 0.9887151107490063, max: 5
# {"metric": "loss", "value": 0.9887151107490063}
# accuracy: (min: 0.28125, avg: 0.7335625, max: 0.96875
# {"metric": "accuracy", "value": 0.7335625}
# q: (min: 23.284751905798913, avg: 29.096316071509122, max: 35.90412081956863
# {"metric": "q", "value": 29.096316071509122}
# score: (min: 230.0, avg: 346.0, max: 490.0
# {"metric": "score", "value": 346.0}
# step: (min: 366, avg: 477, max: 739
# {"metric": "step", "value": 477}
# {"metric": "run", "value": 660}
# loss: (min: 0.20705853402614594, avg: 1.0991911116987467, max: 5
# {"metric": "loss", "value": 1.0991911116987467}
# accuracy: (min: 0.3125, avg: 0.7300625, max: 0.96875
# {"metric": "accuracy", "value": 0.7300625}
# q: (min: 26.07550884306431, avg: 30.292184646594524, max: 41.734768847227095
# {"metric": "q", "value": 30.292184646594524}
# score: (min: 220.0, avg: 756.0, max: 2540.0
# {"metric": "score", "value": 756.0}
# step: (min: 331, avg: 566.4, max: 959
# {"metric": "step", "value": 566.4}
# {"metric": "run", "value": 670}
# loss: (min: 0.1772608757019043, avg: 0.9973281314373016, max: 5
# {"metric": "loss", "value": 0.9973281314373016}
# accuracy: (min: 0.3125, avg: 0.7305, max: 0.96875
# {"metric": "accuracy", "value": 0.7305}
# q: (min: 25.35590047419071, avg: 30.11342095811546, max: 39.13115485608578
# {"metric": "q", "value": 30.11342095811546}
# score: (min: 250.0, avg: 486.0, max: 1250.0
# {"metric": "score", "value": 486.0}
# step: (min: 344, avg: 541.4, max: 958
# {"metric": "step", "value": 541.4}
# {"metric": "run", "value": 680}
# loss: (min: 0.14057788252830505, avg: 1.0733148862570525, max: 5
# {"metric": "loss", "value": 1.0733148862570525}
# accuracy: (min: 0.375, avg: 0.7359375, max: 1.0
# {"metric": "accuracy", "value": 0.7359375}
# q: (min: 26.013638451099396, avg: 30.3427945194903, max: 46.778632477521896
# {"metric": "q", "value": 30.3427945194903}
# loss: (min: 0.14217787981033325, avg: 0.9899903607964515, max: 5
# {"metric": "loss", "value": 0.9899903607964515}
# accuracy: (min: 0.28125, avg: 0.734125, max: 0.96875
# {"metric": "accuracy", "value": 0.734125}
# q: (min: 25.174637350440026, avg: 30.163428022049665, max: 36.80256145060062
# {"metric": "q", "value": 30.163428022049665}
# score: (min: 270.0, avg: 401.0, max: 670.0
# {"metric": "score", "value": 401.0}
# step: (min: 349, avg: 497.9, max: 651
# {"metric": "step", "value": 497.9}
# {"metric": "run", "value": 690}
# loss: (min: 0.1543917953968048, avg: 0.9764912188500166, max: 5
# {"metric": "loss", "value": 0.9764912188500166}
# accuracy: (min: 0.34375, avg: 0.72940625, max: 1.0
# {"metric": "accuracy", "value": 0.72940625}
# q: (min: 25.28720612347126, avg: 30.103561836169362, max: 42.58533919095993
# {"metric": "q", "value": 30.103561836169362}
# score: (min: 170.0, avg: 392.0, max: 720.0
# {"metric": "score", "value": 392.0}
# step: (min: 280, avg: 465.8, max: 615
# {"metric": "step", "value": 465.8}
# {"metric": "run", "value": 700}
# loss: (min: 0.13010841608047485, avg: 0.9840691699683666, max: 5
# {"metric": "loss", "value": 0.9840691699683666}
# accuracy: (min: 0.34375, avg: 0.7388125, max: 0.96875
# {"metric": "accuracy", "value": 0.7388125}
# q: (min: 25.572043305635454, avg: 30.188641775567234, max: 37.01314682364464
# {"metric": "q", "value": 30.188641775567234}
# score: (min: 250.0, avg: 462.0, max: 770.0
# {"metric": "score", "value": 462.0}
# step: (min: 393, avg: 561, max: 727
# {"metric": "step", "value": 561}
# {"metric": "run", "value": 710}
# loss: (min: 0.17344360053539276, avg: 1.0121709252148867, max: 5
# {"metric": "loss", "value": 1.0121709252148867}
# accuracy: (min: 0.375, avg: 0.73834375, max: 0.96875
# {"metric": "accuracy", "value": 0.73834375}
# q: (min: 25.857271900177, avg: 30.196577945002318, max: 42.45909103870392
# {"metric": "q", "value": 30.196577945002318}
# score: (min: 210.0, avg: 526.0, max: 1970.0
# {"metric": "score", "value": 526.0}
# step: (min: 341, avg: 528.2, max: 1020
# {"metric": "step", "value": 528.2}
# {"metric": "run", "value": 720}
# loss: (min: 0.16615483164787292, avg: 0.9244710383415222, max: 5
# {"metric": "loss", "value": 0.9244710383415222}
# accuracy: (min: 0.21875, avg: 0.739625, max: 1.0
# {"metric": "accuracy", "value": 0.739625}
# q: (min: 25.44036835193634, avg: 30.01469899289906, max: 42.48358667433262
# {"metric": "q", "value": 30.01469899289906}
# loss: (min: 0.11774291098117828, avg: 0.9127360367774964, max: 5
# {"metric": "loss", "value": 0.9127360367774964}
# accuracy: (min: 0.34375, avg: 0.73203125, max: 1.0
# {"metric": "accuracy", "value": 0.73203125}
# q: (min: 25.0049394261837, avg: 30.1184119279778, max: 46.07675691902637
# {"metric": "q", "value": 30.1184119279778}
# {"metric": "epsilon", "value": 0.6717636470595075}
# {"metric": "total_step", "value": 360000}
# score: (min: 340.0, avg: 613.0, max: 1390.0
# {"metric": "score", "value": 613.0}
# step: (min: 434, avg: 619.2, max: 953
# {"metric": "step", "value": 619.2}
# {"metric": "run", "value": 730}
# loss: (min: 0.1928970068693161, avg: 1.1523937878757715, max: 5
# {"metric": "loss", "value": 1.1523937878757715}
# accuracy: (min: 0.40625, avg: 0.730875, max: 0.96875
# {"metric": "accuracy", "value": 0.730875}
# q: (min: 25.43317634880543, avg: 30.71763093482256, max: 46.43703031241894
# {"metric": "q", "value": 30.71763093482256}
# score: (min: 230.0, avg: 355.0, max: 780.0
# {"metric": "score", "value": 355.0}
# step: (min: 336, avg: 464.5, max: 612
# {"metric": "step", "value": 464.5}
# {"metric": "run", "value": 740}
# loss: (min: 0.2560729384422302, avg: 1.2144586434066296, max: 5
# {"metric": "loss", "value": 1.2144586434066296}
# accuracy: (min: 0.375, avg: 0.72634375, max: 0.96875
# {"metric": "accuracy", "value": 0.72634375}
# q: (min: 25.79296016573906, avg: 31.180896359934508, max: 46.33498893320561
# {"metric": "q", "value": 31.180896359934508}
# score: (min: 280.0, avg: 487.0, max: 900.0
# {"metric": "score", "value": 487.0}
# step: (min: 379, avg: 520, max: 663
# {"metric": "step", "value": 520}
# {"metric": "run", "value": 750}
# loss: (min: 0.2624863386154175, avg: 1.1878768353760243, max: 5
# {"metric": "loss", "value": 1.1878768353760243}
# accuracy: (min: 0.28125, avg: 0.71896875, max: 0.96875
# {"metric": "accuracy", "value": 0.71896875}
# q: (min: 25.48944290995598, avg: 31.035689518510996, max: 43.0082638156414
# {"metric": "q", "value": 31.035689518510996}
# loss: (min: 0.21838030219078064, avg: 1.1432395941764115, max: 5
# {"metric": "loss", "value": 1.1432395941764115}
# accuracy: (min: 0.375, avg: 0.7305625, max: 0.96875
# {"metric": "accuracy", "value": 0.7305625}
# q: (min: 25.82783813238144, avg: 31.187745847537517, max: 55.88951253652573
# {"metric": "q", "value": 31.187745847537517}
# score: (min: 290.0, avg: 495.0, max: 1370.0
# {"metric": "score", "value": 495.0}
# step: (min: 352, avg: 484.5, max: 745
# {"metric": "step", "value": 484.5}
# {"metric": "run", "value": 760}
# loss: (min: 0.1834341585636139, avg: 1.1646869280040264, max: 5
# {"metric": "loss", "value": 1.1646869280040264}
# accuracy: (min: 0.375, avg: 0.73065625, max: 0.96875
# {"metric": "accuracy", "value": 0.73065625}
# q: (min: 25.748671146631242, avg: 31.108898228877187, max: 45.894520190358165
# {"metric": "q", "value": 31.108898228877187}
# score: (min: 220.0, avg: 444.0, max: 960.0
# {"metric": "score", "value": 444.0}
# step: (min: 313, avg: 474.2, max: 671
# {"metric": "step", "value": 474.2}
# {"metric": "run", "value": 770}
# loss: (min: 0.12845808267593384, avg: 1.1030530622005463, max: 5
# {"metric": "loss", "value": 1.1030530622005463}
# accuracy: (min: 0.25, avg: 0.7265, max: 0.96875
# {"metric": "accuracy", "value": 0.7265}
# q: (min: 26.146194429397582, avg: 30.985076965546906, max: 37.77287447094917
# {"metric": "q", "value": 30.985076965546906}
# score: (min: 220.0, avg: 476.0, max: 1260.0
# {"metric": "score", "value": 476.0}
# step: (min: 362, avg: 499.9, max: 817
# {"metric": "step", "value": 499.9}
# {"metric": "run", "value": 780}
# loss: (min: 0.21455399692058563, avg: 1.1180245050638915, max: 5
# {"metric": "loss", "value": 1.1180245050638915}
# accuracy: (min: 0.375, avg: 0.73584375, max: 1.0
# {"metric": "accuracy", "value": 0.73584375}
# q: (min: 26.02001447439194, avg: 31.0880698263523, max: 45.98306575000286
# {"metric": "q", "value": 31.0880698263523}
# score: (min: 310.0, avg: 507.0, max: 790.0
# {"metric": "score", "value": 507.0}
# step: (min: 367, avg: 548, max: 742
# {"metric": "step", "value": 548}
# {"metric": "run", "value": 790}
# loss: (min: 0.18200454115867615, avg: 1.1175259848684072, max: 5
# {"metric": "loss", "value": 1.1175259848684072}
# accuracy: (min: 0.3125, avg: 0.72721875, max: 0.96875
# {"metric": "accuracy", "value": 0.72721875}
# q: (min: 25.973813794851303, avg: 31.077314898141026, max: 43.88741700530052
# {"metric": "q", "value": 31.077314898141026}
# loss: (min: 0.16495852172374725, avg: 1.0914502200633287, max: 5
# {"metric": "loss", "value": 1.0914502200633287}
# accuracy: (min: 0.3125, avg: 0.72953125, max: 1.0
# {"metric": "accuracy", "value": 0.72953125}
# q: (min: 24.625623773932457, avg: 31.05333742832631, max: 43.59060331463814
# {"metric": "q", "value": 31.05333742832631}
# score: (min: 260.0, avg: 481.0, max: 910.0
# {"metric": "score", "value": 481.0}
# step: (min: 357, avg: 537.4, max: 842
# {"metric": "step", "value": 537.4}
# {"metric": "run", "value": 800}
# loss: (min: 0.15955784916877747, avg: 1.124458898857236, max: 5
# {"metric": "loss", "value": 1.124458898857236}
# accuracy: (min: 0.375, avg: 0.737875, max: 1.0
# {"metric": "accuracy", "value": 0.737875}
# q: (min: 25.925318022966383, avg: 31.097781512366534, max: 44.13834322810173
# {"metric": "q", "value": 31.097781512366534}
# {"metric": "epsilon", "value": 0.6294107058831252}
# {"metric": "total_step", "value": 400000}
# score: (min: 300.0, avg: 601.0, max: 1790.0
# {"metric": "score", "value": 601.0}
# step: (min: 374, avg: 542.1, max: 920
# {"metric": "step", "value": 542.1}
# {"metric": "run", "value": 810}
# loss: (min: 0.18247975409030914, avg: 1.2555013331621885, max: 5
# {"metric": "loss", "value": 1.2555013331621885}
# accuracy: (min: 0.375, avg: 0.72446875, max: 0.96875
# {"metric": "accuracy", "value": 0.72446875}
# q: (min: 25.865911030769347, avg: 31.910898765677512, max: 43.8770323908329
# {"metric": "q", "value": 31.910898765677512}
# loss: (min: 0.24244630336761475, avg: 1.2892333760261536, max: 5
# {"metric": "loss", "value": 1.2892333760261536}
# accuracy: (min: 0.34375, avg: 0.723125, max: 0.96875
# {"metric": "accuracy", "value": 0.723125}
# q: (min: 26.60329334437847, avg: 32.62510765831321, max: 42.85206612408161
# {"metric": "q", "value": 32.62510765831321}
# score: (min: 160.0, avg: 574.0, max: 1150.0
# {"metric": "score", "value": 574.0}
# step: (min: 295, avg: 530.4, max: 761
# {"metric": "step", "value": 530.4}
# {"metric": "run", "value": 820}
# loss: (min: 0.24790719151496887, avg: 1.3302130742669105, max: 5
# {"metric": "loss", "value": 1.3302130742669105}
# accuracy: (min: 0.34375, avg: 0.72953125, max: 0.9375
# {"metric": "accuracy", "value": 0.72953125}
# q: (min: 26.823247388601303, avg: 32.76845188753963, max: 44.783872935771946
# {"metric": "q", "value": 32.76845188753963}
# score: (min: 240.0, avg: 452.0, max: 840.0
# {"metric": "score", "value": 452.0}
# step: (min: 324, avg: 505.8, max: 686
# {"metric": "step", "value": 505.8}
# {"metric": "run", "value": 830}
# loss: (min: 0.2289719134569168, avg: 1.3100409455150366, max: 5
# {"metric": "loss", "value": 1.3100409455150366}
# accuracy: (min: 0.3125, avg: 0.7281875, max: 0.96875
# {"metric": "accuracy", "value": 0.7281875}
# q: (min: 26.990712441802025, avg: 32.57923380017668, max: 59.29843532085419
# {"metric": "q", "value": 32.57923380017668}
# score: (min: 310.0, avg: 659.0, max: 1380.0
# {"metric": "score", "value": 659.0}
# step: (min: 353, avg: 562.6, max: 844
# {"metric": "step", "value": 562.6}
# {"metric": "run", "value": 840}
# loss: (min: 0.19939494132995605, avg: 1.2808281038701534, max: 5
# {"metric": "loss", "value": 1.2808281038701534}
# accuracy: (min: 0.375, avg: 0.7331875, max: 0.96875
# {"metric": "accuracy", "value": 0.7331875}
# q: (min: 26.433898091316223, avg: 32.68168830367178, max: 43.1965114235878
# {"metric": "q", "value": 32.68168830367178}
# score: (min: 170.0, avg: 687.0, max: 1850.0
# {"metric": "score", "value": 687.0}
# step: (min: 258, avg: 516.2, max: 987
# {"metric": "step", "value": 516.2}
# {"metric": "run", "value": 850}
# loss: (min: 0.25015461444854736, avg: 1.2995189891159535, max: 5
# {"metric": "loss", "value": 1.2995189891159535}
# accuracy: (min: 0.375, avg: 0.7269375, max: 0.96875
# {"metric": "accuracy", "value": 0.7269375}
# q: (min: 27.005443505048753, avg: 32.722089783628284, max: 43.34035773277283
# {"metric": "q", "value": 32.722089783628284}
# loss: (min: 0.2097810059785843, avg: 1.1621835211515426, max: 5
# {"metric": "loss", "value": 1.1621835211515426}
# accuracy: (min: 0.375, avg: 0.7265, max: 0.96875
# {"metric": "accuracy", "value": 0.7265}
# q: (min: 27.50000067949295, avg: 32.55440225007177, max: 40.98662306189537
# {"metric": "q", "value": 32.55440225007177}
# score: (min: 250.0, avg: 759.0, max: 1990.0
# {"metric": "score", "value": 759.0}
# step: (min: 342, avg: 611.7, max: 824
# {"metric": "step", "value": 611.7}
# {"metric": "run", "value": 860}
# loss: (min: 0.19312115013599396, avg: 1.2820385330617428, max: 5
# {"metric": "loss", "value": 1.2820385330617428}
# accuracy: (min: 0.28125, avg: 0.73378125, max: 0.96875
# {"metric": "accuracy", "value": 0.73378125}
# q: (min: 26.842576078772545, avg: 32.52267803805977, max: 47.261818329691884
# {"metric": "q", "value": 32.52267803805977}
# score: (min: 350.0, avg: 502.0, max: 970.0
# {"metric": "score", "value": 502.0}
# step: (min: 411, avg: 546.8, max: 875
# {"metric": "step", "value": 546.8}
# {"metric": "run", "value": 870}
# loss: (min: 0.20408299565315247, avg: 1.2062577981501819, max: 5
# {"metric": "loss", "value": 1.2062577981501819}
# accuracy: (min: 0.34375, avg: 0.72803125, max: 0.96875
# {"metric": "accuracy", "value": 0.72803125}
# q: (min: 26.122815621495246, avg: 32.4057516543746, max: 54.47666322261095
# {"metric": "q", "value": 32.4057516543746}
# loss: (min: 0.17724093794822693, avg: 1.232737771421671, max: 5
# {"metric": "loss", "value": 1.232737771421671}
# accuracy: (min: 0.40625, avg: 0.72890625, max: 1.0
# {"metric": "accuracy", "value": 0.72890625}
# q: (min: 26.98025327593088, avg: 32.6097754844436, max: 46.732290853858
# {"metric": "q", "value": 32.6097754844436}
# score: (min: 170.0, avg: 454.0, max: 1150.0
# {"metric": "score", "value": 454.0}
# step: (min: 339, avg: 478.6, max: 665
# {"metric": "step", "value": 478.6}
# {"metric": "run", "value": 880}
# {"metric": "epsilon", "value": 0.5870577647067429}
# {"metric": "total_step", "value": 440000}
# loss: (min: 0.20687606930732727, avg: 1.4062837867587805, max: 5
# {"metric": "loss", "value": 1.4062837867587805}
# accuracy: (min: 0.40625, avg: 0.72325, max: 1.0
# {"metric": "accuracy", "value": 0.72325}
# q: (min: 27.377407059073448, avg: 34.425546379265484, max: 58.73283005475998
# {"metric": "q", "value": 34.425546379265484}
# score: (min: 270.0, avg: 645.0, max: 1170.0
# {"metric": "score", "value": 645.0}
# step: (min: 355, avg: 567.3, max: 781
# {"metric": "step", "value": 567.3}
# {"metric": "run", "value": 890}
# loss: (min: 0.32075196504592896, avg: 1.4660728417634965, max: 5
# {"metric": "loss", "value": 1.4660728417634965}
# accuracy: (min: 0.3125, avg: 0.71390625, max: 0.96875
# {"metric": "accuracy", "value": 0.71390625}
# q: (min: 28.627703468203546, avg: 36.07389647729635, max: 46.20288784146309
# {"metric": "q", "value": 36.07389647729635}
